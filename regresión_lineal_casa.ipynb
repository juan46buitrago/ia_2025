# %% [markdown]
# <a href="https://colab.research.google.com/github/juan46buitrago/ia_2025/blob/main/regresi%C3%B3n_lineal_casa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

# %%
data=pd.read_excel('/content/Salary.xlsx')
data.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
df=pd.DataFrame(data) #crear un dara frame
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
df.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
X=df['YearsExperience'] #variable independiente
Y= df['Salary'] #variabe dependiente
plt.figure(figsize=(10,6))
plt.scatter(X,Y, color ="pink", label="Datos reales")
plt.title("salari vs los años de experiecia")
plt.legend()
plt.grid(True)
plt.show()

# %%
#ajuestando los datos a un modelo de regresion lineal
model=LinearRegression()
model.fit(X.values.reshape(-1, 1),Y)

#generar prediccion
y_pred=model.predict(X.values.reshape(-1, 1))

#hallar el R2
r2=r2_score(Y,y_pred)

# %%
plt.figure(figsize=(10,6))
plt.scatter(X,Y, color ="pink", label="Datos reales")
plt.plot(X,y_pred, color="red",linewidth=2 ,label="regresion lineal")
plt.xlabel("años de experiencia")
plt.ylabel("salario")
plt.title("salari vs los años de experiecia")
plt.legend()
plt.grid(True)
plt.show()

print(f"Ecuacuion de la recta :y {model.coef_[0]:.2f}x+{model.intercept_:2f}")
print(f"coeficien de deerminacion (R^2): {r2:.2f}")
# Out:
# Ecuacuion de la recta :y 8731.94x+28859.526195
# coeficien de deerminacion (R^2): 0.97

# %%
data2=pd.read_csv('/content/dataset_edad_precio_seguro.csv')
data2.head()
# Out:
#    Edad  PrecioSeguro
# 0    18           200
# 1    22           250
# 2    25           300
# 3    30           400
# 4    35           500

# %%
X=data2['Edad']
Y=data2['PrecioSeguro']



plt.figure(figsize=(10,6))
plt.scatter(X,Y, color ="pink", label="Datos reales")

plt.xlabel("aprecio del segurovs edad")
plt.ylabel("edad")
plt.title("precioSeguro")
plt.legend()
plt.grid(True)
plt.show()

# %%
#ajuestando los datos a un modelo de regresion lineal
model2=LinearRegression()
model2.fit(X.values.reshape(-1, 1),Y)

#generar prediccion
y_pred2=model2.predict(X.values.reshape(-1, 1))

#hallar el R2
r2_seguro=r2_score(Y,y_pred2)

# %%
plt.figure(figsize=(10,6))
plt.scatter(X,Y, color ="pink", label="Datos reales")
plt.plot(X,y_pred2, color="red",linewidth=2 ,label="regresion lineal")
plt.xlabel("Edad")
plt.ylabel("Precio seguro")
plt.title("Preco seguro vs Edad")
plt.legend()
plt.grid(True)
plt.show()

print(f"Ecuacuion de la recta :y {model2.coef_[0]:.2f}x+{model2.intercept_:2f}")
print(f"coeficien de deerminacion (R^2): {r2_seguro:.2f}")
# Out:
# Ecuacuion de la recta :y 22.81x+-266.595289
# coeficien de deerminacion (R^2): 0.98

# %%
data3=pd.read_csv('/content/house_prices_large.csv')
data3.head()
# Out:
#    House_Size       Price
# 0  143.635030  417.428104
# 1  287.678577  601.054220
# 2  232.998485  588.407166
# 3  199.664621  539.925605
# 4   89.004660  338.197911

# %%
X=data3["House_Size"]
Y=data3['Price']



plt.figure(figsize=(10,6))
plt.scatter(X,Y, color ="pink", label="Datos reales")

plt.xlabel("House_Size")
plt.ylabel("Price")
plt.title("price vs house size")
plt.legend()
plt.grid(True)
plt.show()

# %%
#ajuestando los datos a un modelo de regresion lineal
model3=LinearRegression()
model3.fit(X.values.reshape(-1, 1),Y)

#generar prediccion
y_pred3=model3.predict(X.values.reshape(-1, 1))

#hallar el R2
r3_seguro=r2_score(Y,y_pred3)

# %%
plt.figure(figsize=(10,6))
plt.scatter(X,Y, color ="pink", label="Datos reales")
plt.plot(X,y_pred3, color="red",linewidth=2 ,label="regresion lineal") # Use y_pred3
plt.xlabel("House Size") # Corrected label
plt.ylabel("Price") # Corrected label
plt.title("Price vs House Size") # Corrected title
plt.legend()
plt.grid(True)
plt.show()

print(f"Ecuacuion de la recta :y {model3.coef_[0]:.2f}x+{model3.intercept_:2f}")
print(f"coeficien de deerminacion (R^2): {r2_seguro:.2f}") # Corrected variable name
# Out:
# Ecuacuion de la recta :y 1.77x+160.286865
# coeficien de deerminacion (R^2): 0.98
