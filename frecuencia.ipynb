# %% [markdown]
# <a href="https://colab.research.google.com/github/juan46buitrago/ia_2025/blob/main/frecuencia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##actividad frecuencia con ia

# %% [markdown]
# #tabla

# %%
import pandas as pd


from google.colab import files
uploaded = files.upload()


df = pd.read_excel("tabla_frecuencias.xlsx")


df.head()
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)


df
# Out:
#      <input type="file" id="files-ef3e068d-7894-44ff-be8c-1e1819c4fd46" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ef3e068d-7894-44ff-be8c-1e1819c4fd46">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# #Ground true

# %% [markdown]
# ![tabla groundtrue.png](data:image/png;base64,...)

# %% [markdown]
# ![word cloud groundtrue.png](data:image/png;base64,...)

# %% [markdown]
# #chatgpt

# %% [markdown]
# ![Captura de pantalla 2025-09-09 112641.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de pantalla 2025-09-09 112709.png](data:image/png;base64,...)

# %% [markdown]
# #copilot

# %% [markdown]
# ![Captura de pantalla 2025-09-09 114427.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de pantalla 2025-09-09 114449.png](data:image/png;base64,...)

# %% [markdown]
# #grok

# %% [markdown]
# ![Captura de pantalla 2025-09-09 113359.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de pantalla 2025-09-09 113531.png](data:image/png;base64,...)

# %% [markdown]
# #claude

# %% [markdown]
# ![Captura de pantalla 2025-09-09 113818.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de pantalla 2025-09-09 113725.png](data:image/png;base64,...)
